# %%
# importing the libraries for analysis and visualisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd C:\Users\shaqu\Desktop\company questionaires\Dataleads
# Out:
# C:\Users\shaqu\Desktop\company questionaires\Dataleads

# %%
# a vairiable created for our main dataset to read the file easily
data= 'masterfile.csv'

# %%
# reading the dataset
df= pd.read_csv(data)
df
# Out:
#            Entity Code  Year Execution  Meningitis (deaths)  \
# 0     Afghanistan  AFG  2007        15          9121.085992
# 1     Afghanistan  AFG  2008        17          8387.057275
# 2     Afghanistan  AFG  2009         0          7318.273004
# 3     Afghanistan  AFG  2010       NaN          7154.319444
# 4     Afghanistan  AFG  2011         2          6919.757958
# ...           ...  ...   ...       ...                  ...
# 6681     Zimbabwe  ZWE  2003       NaN          1842.738749
# 6682     Zimbabwe  ZWE  2004       NaN          1897.210030
# 6683     Zimbabwe  ZWE  2005       NaN          1972.102293
# 6684     Zimbabwe  ZWE  2006       NaN          2021.646371
# 6685     Zimbabwe  ZWE  2017       NaN          1677.007331
#
#       Lower respiratory infections (deaths)  \
# 0                              29066.442137
# 1                              26623.480551
# 2                              24792.335792
# 3                              23950.017286
# 4                              23115.144836
# ...                                     ...
# 6681                           11671.507529
# 6682                           11912.787792
# 6683                           12332.751355
# 6684                           12679.065309
# 6685                           12369.654705
#
#       Intestinal infectious diseases (deaths)  \
# 0                                  461.195202
# 1                                  437.718960
# 2                                  415.776634
# 3                                  332.253781
# 4                                  299.758258
# ...                                       ...
# 6681                                15.290586
# 6682                                15.858873
# 6683                                17.191164
# 6684                                18.191677
# 6685                                      NaN
#
#       Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# 0                              1846.996686              1199.0
# 1                              1681.270324              1092.0
# 2                              1568.095029              1065.0
# 3                              1541.841155              1157.0
# 4                              1468.203744              1525.0
# ...                                    ...                 ...
# 6681                           3001.007608                 0.0
# 6682                           2987.046148                 NaN
# 6683                           3154.257667                 NaN
# 6684                           3252.216148                 0.0
# 6685                           3111.873502                 0.0
#
#       Cardiovascular diseases (deaths)  ...  Neonatal disorders (deaths)  \
# 0                         53532.680495  ...                 28477.081107
# 1                         53402.322328  ...                 28234.015837
# 2                         53024.450772  ...                 27897.481121
# 3                         52712.687821  ...                 27018.706951
# 4                         52815.737495  ...                 27198.628720
# ...                                ...  ...                          ...
# 6681                      18013.633317  ...                  7976.334894
# 6682                      18424.762242  ...                  8244.393421
# 6683                      18523.610968  ...                  8613.067778
# 6684                      18478.629953  ...                  9022.460105
# 6685                      16976.902369  ...                  8411.915534
#
#       Alcohol use disorders (deaths)  Natural disasters (deaths)  \
# 0                          96.027592                  296.000026
# 1                          98.308461                    0.000000
# 2                         100.088778                  101.000000
# 3                         102.648045                  349.999997
# 4                         105.565020                   62.000000
# ...                              ...                         ...
# 6681                       80.554883                   10.000000
# 6682                       81.526343                    0.000000
# 6683                       81.773393                    0.000000
# 6684                       81.992591                    0.000000
# 6685                       77.192339                    0.000000
#
#       Diarrheal diseases (deaths)  Heat (hot and cold exposure) (deaths)  \
# 0                    10366.124292                             160.930121
# 1                     8994.815981                             156.860722
# 2                     7996.529795                             152.144044
# 3                     7530.046788                             151.683206
# 4                     7053.113394                             150.311602
# ...                           ...                                    ...
# 6681                  4076.907435                              44.492707
# 6682                  3975.116771                              45.307413
# 6683                  4138.829612                              46.063561
# 6684                  4337.462149                              46.823812
# 6685                  4602.593760                              41.433611
#
#       Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 0                           1941.282198       1378.571549        8216.000975
# 1                           1765.980756       1411.783229        6748.999931
# 2                           1647.863334       1428.808015        7562.996178
# 3                           1619.355103       1457.157631        8117.000620
# 4                           1543.182842       1496.192418        9061.000023
# ...                                 ...               ...                ...
# 6681                        3060.919036       2774.913349           5.000000
# 6682                        3048.142154       2868.490026           1.000000
# 6683                        3215.816535       2897.899125           3.000000
# 6684                        3313.276491       2894.015527           0.000000
# 6685                        3157.591804       2647.468528           5.000000
#
#       Diabetes (deaths)  Poisonings (deaths)
# 0           4691.007199           305.207239
# 1           4750.240999           300.246001
# 2           4784.225283           295.413907
# 3           4825.933668           304.808594
# 4           4954.293898           311.997686
# ...                 ...                  ...
# 6681        2464.305902           384.913007
# 6682        2544.638684           388.287626
# 6683        2581.363814           396.433573
# 6684        2609.324460           401.035836
# 6685        2746.739645           405.377266
#
# [6686 rows x 37 columns]

# %%
# for displaying the maximum columns
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#         Entity Code  Year Execution  Meningitis (deaths)  \
# 0  Afghanistan  AFG  2007        15          9121.085992
# 1  Afghanistan  AFG  2008        17          8387.057275
# 2  Afghanistan  AFG  2009         0          7318.273004
# 3  Afghanistan  AFG  2010       NaN          7154.319444
# 4  Afghanistan  AFG  2011         2          6919.757958
# 5  Afghanistan  AFG  2012        14          6631.942601
# 6  Afghanistan  AFG  2013         2          6774.892059
# 7  Afghanistan  AFG  2014         6          6795.163086
# 8  Afghanistan  AFG  2015         1          6667.310323
# 9  Afghanistan  AFG  2016         6          6672.896174
#
#    Lower respiratory infections (deaths)  \
# 0                           29066.442137
# 1                           26623.480551
# 2                           24792.335792
# 3                           23950.017286
# 4                           23115.144836
# 5                           22155.754481
# 6                           22417.229523
# 7                           22167.851944
# 8                           21627.195092
# 9                           21359.253797
#
#    Intestinal infectious diseases (deaths)  \
# 0                               461.195202
# 1                               437.718960
# 2                               415.776634
# 3                               332.253781
# 4                               299.758258
# 5                               302.255411
# 6                               402.174478
# 7                               427.419194
# 8                               432.539812
# 9                               435.834889
#
#    Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# 0                           1846.996686              1199.0
# 1                           1681.270324              1092.0
# 2                           1568.095029              1065.0
# 3                           1541.841155              1157.0
# 4                           1468.203744              1525.0
# 5                           1406.214788              3521.0
# 6                           1423.283631              3709.0
# 7                           1421.239332              5414.0
# 8                           1384.973801              6216.0
# 9                           1363.976372              6142.0
#
#    Cardiovascular diseases (deaths)  Dementia (deaths)  \
# 0                      53532.680495        2458.120490
# 1                      53402.322328        2496.968317
# 2                      53024.450772        2537.090789
# 3                      52712.687821        2575.132021
# 4                      52815.737495        2615.883604
# 5                      52961.704530        2657.841812
# 6                      53387.554213        2701.404559
# 7                      53858.559775        2747.997169
# 8                      54221.895746        2786.542338
# 9                      54963.454084        2838.014437
#
#    Kidney disease (deaths)  Respiratory diseases (deaths)  \
#
# 0                       96.027592                  296.000026
# 1                       98.308461                    0.000000
# 2                      100.088778                  101.000000
# 3                      102.648045                  349.999997
# 4                      105.565020                   62.000000
# 5                      108.281688                  333.000006
# 6                      111.728148                  154.999997
# 7                      115.048500                  574.999987
# 8                      117.900202                  191.999999
# 9                      121.276505                   77.999999
#
#    Diarrheal diseases (deaths)  Heat (hot and cold exposure) (deaths)  \
# 0                 10366.124292                             160.930121
# 1                  8994.815981                             156.860722
# 2                  7996.529795                             152.144044
# 3                  7530.046788                             151.683206
# 4                  7053.113394                             150.311602
# 5                  6577.552474                             193.388959
# 6                  6624.194797                             150.711361
# 7                  6489.733878                             151.614405
# 8                  6220.600683                             150.212098
# 9                  6058.453264                             150.879643
#
#    Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 0                        1941.282198       1378.571549        8216.000975
# 1                        1765.980756       1411.783229        6748.999931
# 2                        1647.863334       1428.808015        7562.996178
# 3                        1619.355103       1457.157631        8117.000620
# 4                        1543.182842       1496.192418        9061.000023
# 5                        1478.263352       1528.384710       11332.990002
# 6                        1496.911285       1574.109821       11816.974732
# 7                        1494.442760       1611.773210       17949.996108
# 8                        1456.567599       1638.922690       23661.951467
# 9                        1434.740512       1674.423809       28050.866788
#
#    Diabetes (deaths)  Poisonings (deaths)
# 0        4691.007199           305.207239
# 1        4750.240999           300.246001
# 2        4784.225283           295.413907
# 3        4825.933668           304.808594
# 4        4954.293898           311.997686
# 5        5075.765738           316.256517
# 6        5238.074827           333.591091
# 7        5416.396431           342.890235
# 8        5591.446503           345.625886
# 9        5824.419892           354.722887

# %%
#checking the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6686 entries, 0 to 6685
# Data columns (total 37 columns):
# Entity                                     6686 non-null object
# Code                                       5545 non-null object
# Year                                       6686 non-null int64
# Execution                                  267 non-null object
# Meningitis (deaths)                        6468 non-null float64
# Lower respiratory infections (deaths)      6468 non-null float64
# Intestinal infectious diseases (deaths)    6156 non-null float64
# Protein-energy malnutrition (deaths)       6468 non-null float64
# Terrorism (deaths)                         2891 non-null float64
# Cardiovascular diseases (deaths)           6468 non-null float64
# Dementia (deaths)                          6468 non-null float64
# Kidney disease (deaths)                    6468 non-null float64
# Respiratory diseases (deaths)              6468 non-null float64
# Liver diseases (deaths)                    6468 non-null float64
# Digestive diseases (deaths)                6468 non-null float64
# Hepatitis (deaths)                         6468 non-null float64
# Cancers (deaths)                           6468 non-null float64
# Parkinson disease (deaths)                 6468 non-null float64
# Fire (deaths)                              6468 non-null float64
# Malaria (deaths)                           6468 non-null float64
# Drowning (deaths)                          6468 non-null float64
# Homicide (deaths)                          6468 non-null float64
# HIV/AIDS (deaths)                          6468 non-null float64
# Drug use disorders (deaths)                6468 non-null float64
# Tuberculosis (deaths)                      6468 non-null float64
# Road injuries (deaths)                     6468 non-null float64
# Maternal disorders (deaths)                6468 non-null float64
# Neonatal disorders (deaths)                6468 non-null float64
# Alcohol use disorders (deaths)             6468 non-null float64
# Natural disasters (deaths)                 6468 non-null float64
# Diarrheal diseases (deaths)                6468 non-null float64
# Heat (hot and cold exposure) (deaths)      6468 non-null float64
# Nutritional deficiencies (deaths)          6468 non-null float64
# Suicide (deaths)                           6468 non-null float64
# Conflict (deaths)                          6468 non-null float64
# Diabetes (deaths)                          6468 non-null float64
# Poisonings (deaths)                        6468 non-null float64
# dtypes: float64(33), int64(1), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#               Year  Meningitis (deaths)  \
# count  6686.000000          6468.000000
# mean   2003.469488          7780.768953
# std       8.076979         34193.574520
# min    1990.000000             0.214225
# 25%    1996.000000            32.844678
# 50%    2003.000000           263.326804
# 75%    2010.000000          2093.966414
# max    2017.000000        462419.725356
#
#        Lower respiratory infections (deaths)  \
# count                           6.468000e+03
# mean                            5.852767e+04
# std                             2.326967e+05
# min                             6.462032e+00
# 25%                             6.106540e+02
# 50%                             4.313073e+03
# 75%                             1.862988e+04
# max                             3.415941e+06
#
#        Intestinal infectious diseases (deaths)  \
# count                              6156.000000
# mean                               3430.235605
# std                               19322.536951
# min                                   0.002202
# 25%                                   0.476189
# 50%                                   6.272934
# 75%                                 261.856157
# max                              215726.866669
#
#        Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# count                           6468.000000         2891.000000
# mean                            7968.171555          349.235905
# std                            35566.546169         1917.143788
# min                                0.035425            0.000000
# 25%                                8.939738            0.000000
# 50%                              139.132563            5.000000
# 75%                             2337.484551           60.000000
# max                           548711.952423        44490.000000
#
#        Cardiovascular diseases (deaths)  Dementia (deaths)  \
# count                      6.468000e+03       6.468000e+03
# mean                       3.002555e+05       3.460315e+04
# std                        1.173251e+06       1.417552e+05
# min                        3.767702e+01       2.741968e+00
# 25%                        4.225455e+03       3.398984e+02
# 50%                        1.885626e+04       1.708948e+03
# 75%                        8.015074e+04       9.514314e+03
# max                        1.779095e+07       2.514619e+06
#
#        Kidney disease (deaths)  Respiratory diseases (deaths)  \
# count             6.468000e+03                   6.468000e+03
# mean              1.788960e+04                   7.129487e+04
# std               7.101438e+04                   3.068237e+05
# min               1.897796e+00                   7.297981e+00
# 25%               2.598338e+02                   4.956917e+02
# 50%               1.339441e+03                   2.442531e+03
# 75%               5.230333e+03                   1.293316e+04
# max               1.230168e+06                   3.914196e+06
#
#        Liver diseases (deaths)  Digestive diseases (deaths)  \
# count             6.468000e+03                 6.468000e+03
# mean              2.270430e+04                 4.129042e+04
# std               8.683915e+04                 1.575667e+05
# min               4.263551e+00                 7.708550e+00
# 25%               2.378749e+02                 5.138457e+02
# 50%               1.501693e+03                 2.968175e+03
# 75%               6.751774e+03                 1.325964e+04
# max               1.322868e+06                 2.377685e+06
#
#        Hepatitis (deaths)  Cancers (deaths)  Parkinson disease (deaths)  \
# count         6468.000000      6.468000e+03                 6468.000000
# mean          2695.432230      1.562091e+05                 4840.615200
# std          12839.935853      6.201771e+05                19572.923607
# min              0.027978      2.291360e+01                    0.502997
# 25%              8.155722      1.954966e+03                   52.126626
# 50%             82.818471      8.516673e+03                  256.801569
# 75%            426.029074      4.390101e+04                 1336.191572
# max         150109.303586      9.556245e+06               340639.167844
#
#        Fire (deaths)  Malaria (deaths)  Drowning (deaths)  Homicide (deaths)  \
# count    6468.000000       6468.000000        6468.000000        6468.000000
# mean     2748.497633      16691.871502        8328.395166        8614.452276
# std     10621.054918      84075.483703       35557.851530       33094.585349
# min         0.234315          0.000000           0.429421           0.552287
# 25%        40.436781          0.000000          62.244530          72.137561
# 50%       221.446172          1.811186         398.532075         412.586660
# 75%       860.953032        675.641291        1605.184232        1967.307988
# max    150822.912445     934553.222151      533767.266851      446675.276612
#
#        HIV/AIDS (deaths)  Drug use disorders (deaths)  Tuberculosis (deaths)  \
# count       6.468000e+03                  6468.000000           6.468000e+03
# mean        2.808229e+04                  2276.504819           2.879106e+04
# std         1.363146e+05                  9663.540155           1.273040e+05
# min         0.000000e+00                     0.179388           7.598407e-02
# 25%         2.583965e+01                    17.214436           5.917619e+01
# 50%         2.720479e+02                    75.975217           7.459354e+02
# 75%         4.897498e+03                   460.087489           5.795154e+03
# max         1.953141e+06                166612.548448           1.624708e+06
#
#        Road injuries (deaths)  Maternal disorders (deaths)  \
# count            6.468000e+03                  6468.000000
# mean             2.555972e+04                  5302.181737
# std              1.007707e+05                 24099.242819
# min              2.404754e+00                     0.031773
# 25%              3.355947e+02                     9.675223
# 50%              1.854405e+03                   124.967627
# 75%              7.696999e+03                  1435.630048
# max              1.299939e+06                327342.638507
#
#        Neonatal disorders (deaths)  Alcohol use disorders (deaths)  \
# count                 6.468000e+03                     6468.000000
# mean                  4.813689e+04                     3525.876073
# std                   2.115090e+05                    14336.535999
# min                   4.363093e-01                        0.293634
# 25%                   2.046254e+02                       23.700635
# 50%                   1.791409e+03                      158.916099
# 75%                   1.308573e+04                      696.238005
# max                   2.986076e+06                   190843.575458
#
#        Natural disasters (deaths)  Diarrheal diseases (deaths)  \
# count                 6468.000000                 6.468000e+03
# mean                  1032.806516                 3.918273e+04
# std                  11262.768093                 1.873208e+05
# min                      0.000000                 1.971131e-01
# 25%                      0.000000                 3.950165e+01
# 50%                      1.000000                 6.339398e+02
# 75%                     36.000000                 7.544887e+03
# max                 248454.699157                 2.578292e+06
#
#        Heat (hot and cold exposure) (deaths)  \
# count                            6468.000000
# mean                             1355.710222
# std                              6023.004366
# min                                 0.098110
# 25%                                 7.548353
# 50%                                56.304225
# 75%                               216.115514
# max                            115382.599926
#
#        Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# count                        6468.000000       6468.000000        6468.000000
# mean                         8839.247637      16428.863277        2172.277617
# std                         39182.734641      65583.009738       17511.328435
# min                             0.078023          1.492135           0.000000
# 25%                            13.854870        187.883497           0.000000
# 50%                           190.419356        792.613953           1.000045
# 75%                          2516.917188       4082.206487          89.000000
# max                        601954.402277     859246.631195      569177.531650
#
#        Diabetes (deaths)  Poisonings (deaths)
# count       6.468000e+03          6468.000000
# mean        1.948290e+04          1636.750538
# std         7.677205e+04          6673.775283
# min         2.660915e+00             0.117638
# 25%         3.618043e+02            13.518640
# 50%         1.453246e+03            94.992363
# 75%         6.433005e+03           387.416193
# max         1.369849e+06         83257.443538

# %%
# sorted the value into general float format
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 0                           1941.282          1378.572           8216.001
# 1                           1765.981          1411.783           6749.000
# 2                           1647.863          1428.808           7562.996
# 3                           1619.355          1457.158           8117.001
# 4                           1543.183          1496.192           9061.000
#
#    Diabetes (deaths)  Poisonings (deaths)
# 0           4691.007              305.207
# 1           4750.241              300.246
# 2           4784.225              295.414
# 3           4825.934              304.809
# 4           4954.294              311.998

# %%
## create a new column for total death which sums up all the deaths from different diseases
df['Total_Deaths'] = df.iloc[:, 4::].sum(axis= 1)

# %%
m= df
m.loc['Diseases deaths']=df.iloc[:, 4:].sum(axis= 0)
df= pd.DataFrame(m)
df
# Out:
#                       Entity Code     Year Execution  Meningitis (deaths)  \
# 0                Afghanistan  AFG 2007.000        15             9121.086
# 1                Afghanistan  AFG 2008.000        17             8387.057
# 2                Afghanistan  AFG 2009.000         0             7318.273
# 3                Afghanistan  AFG 2010.000       NaN             7154.319
# 4                Afghanistan  AFG 2011.000         2             6919.758
# ...                      ...  ...      ...       ...                  ...
# 6682                Zimbabwe  ZWE 2004.000       NaN             1897.210
# 6683                Zimbabwe  ZWE 2005.000       NaN             1972.102
# 6684                Zimbabwe  ZWE 2006.000       NaN             2021.646
# 6685                Zimbabwe  ZWE 2017.000       NaN             1677.007
# Diseases deaths          NaN  NaN      nan       NaN         50326013.590
#
#                  Lower respiratory infections (deaths)  \
# 0                                            29066.442
# 1                                            26623.481
# 2                                            24792.336
# 3                                            23950.017
# 4                                            23115.145
# ...                                                ...
# 6682                                         11912.788
# 6683                                         12332.751
# 6684                                         12679.065
# 6685                                         12369.655
# Diseases deaths                          378556981.603
#
#                  Intestinal infectious diseases (deaths)  \
# 0                                                461.195
# 1                                                437.719
# 2                                                415.777
# 3                                                332.254
# 4                                                299.758
# ...                                                  ...
# 6682                                              15.859
# 6683                                              17.191
# 6684                                              18.192
# 6685                                                 nan
# Diseases deaths                             21116530.386
#
#                  Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# 0                                            1846.997            1199.000
# 1                                            1681.270            1092.000
# 2                                            1568.095            1065.000
# 3                                            1541.841            1157.000
# 4                                            1468.204            1525.000
# ...                                               ...                 ...
# 6682                                         2987.046                 nan
# 6683                                         3154.258                 nan
# 6684                                         3252.216               0.000
# 6685                                         3111.874               0.000
# Diseases deaths                          51538133.617         1009641.000
#
#                  Cardiovascular diseases (deaths)  Dementia (deaths)  \
# 0                                       53532.680           2458.120
# 1                                       53402.322           2496.968
# 2                                       53024.451           2537.091
# 3                                       52712.688           2575.132
# 4                                       52815.737           2615.884
# ...                                           ...                ...
# 6682                                    18424.762           1410.146
# 6683                                    18523.611           1385.625
# 6684                                    18478.630           1363.448
# 6685                                    16976.902           1246.101
# Diseases deaths                    1942052678.650      223813163.131
#
#                  Kidney disease (deaths)  Respiratory diseases (deaths)  \
# 0                               3715.278                       6896.159
# 1                               3685.770                       6855.287
# 2                               3661.267                       6778.041
# 3                               3682.829                       6734.346
# 4                               3691.336                       6708.237
# ...                                  ...                            ...
# 6682                            1728.791                       3761.851
# 6683                            1743.115                       3814.769
# 6684                            1756.603                       3814.640
# 6685                            1739.892                       3411.961
# Diseases deaths            115709952.111                  461135205.578
#
#                  Liver diseases (deaths)  Digestive diseases (deaths)  \
#
#                  Natural disasters (deaths)  Diarrheal diseases (deaths)  \
# 0                                   296.000                    10366.124
# 1                                     0.000                     8994.816
# 2                                   101.000                     7996.530
# 3                                   350.000                     7530.047
# 4                                    62.000                     7053.113
# ...                                     ...                          ...
# 6682                                  0.000                     3975.117
# 6683                                  0.000                     4138.830
# 6684                                  0.000                     4337.462
# 6685                                  0.000                     4602.594
# Diseases deaths                 6680192.544                253433867.629
#
#                  Heat (hot and cold exposure) (deaths)  \
# 0                                              160.930
# 1                                              156.861
# 2                                              152.144
# 3                                              151.683
# 4                                              150.312
# ...                                                ...
# 6682                                            45.307
# 6683                                            46.064
# 6684                                            46.824
# 6685                                            41.434
# Diseases deaths                            8768733.718
#
#                  Nutritional deficiencies (deaths)  Suicide (deaths)  \
# 0                                         1941.282          1378.572
# 1                                         1765.981          1411.783
# 2                                         1647.863          1428.808
# 3                                         1619.355          1457.158
# 4                                         1543.183          1496.192
# ...                                            ...               ...
# 6682                                      3048.142          2868.490
# 6683                                      3215.817          2897.899
# 6684                                      3313.276          2894.016
# 6685                                      3157.592          2647.469
# Diseases deaths                       57172253.718     106261887.679
#
#                  Conflict (deaths)  Diabetes (deaths)  Poisonings (deaths)  \
# 0                         8216.001           4691.007              305.207
# 1                         6749.000           4750.241              300.246
# 2                         7562.996           4784.225              295.414
# 3                         8117.001           4825.934              304.809
# 4                         9061.000           4954.294              311.998
# ...                            ...                ...                  ...
# 6682                         1.000           2544.639              388.288
# 6683                         3.000           2581.364              396.434
# 6684                         0.000           2609.324              401.036
# 6685                         5.000           2746.740              405.377
# Diseases deaths       14050291.624      126015384.514         10586502.481
#
#                   Total_Deaths
# 0                   212045.815
# 1                   204565.358
# 2                   199858.591
# 3                   198262.790
# 4                   198048.470
# ...                        ...
# 6682                206685.131
# 6683                208249.797
# 6684                207466.640
# 6685                114590.611
# Diseases deaths 6452926400.665
#
# [6687 rows x 38 columns]

# %%
df['Total_Deaths']
# Out:
# 0                     212045.815
# 1                     204565.358
# 2                     199858.591
# 3                     198262.790
# 4                     198048.470
#                        ...
# 6682                  206685.131
# 6683                  208249.797
# 6684                  207466.640
# 6685                  114590.611
# Diseases deaths   6452926400.665
# Name: Total_Deaths, Length: 6687, dtype: float64

# %% [markdown]
# # Section I: SEGREGATION
# You are provided a csv file (attached). Using python libraries at your disposal, run a loop to extract up to 10 datasets (preferably .xlxs format) based on different criterias (e.g., country, prevalence, etc.). Kindly document your steps as you go through the process.

# %%
## we checked single column unique values!!
coutry_array= df['Entity'].unique()

## we converted array to list for using the list method!!
country_lst = coutry_array.tolist()

# %%
## created a loop to extract different datasets from the same masterfile!!

# for i in country_lst:
#     grp = df.groupby(df.Entity) ## grouping the columns
#     temp = grp.get_group(i)
#     print(f'we created dataset from the masterfile: { i}')
#     temp.to_excel(i + ".xlsx")

# %%
cd C:\Users\shaqu\Desktop\company questionaires\Dataleads\outputs
# Out:
# C:\Users\shaqu\Desktop\company questionaires\Dataleads\outputs

# %%
## created a loop to extract 10 different datasets from the same masterfile with respect to coutries name!!

for i in country_lst[:10]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created dataset from the masterfile: { i}')
    temp.to_excel(i + ".xlsx")
# Out:
# we created dataset from the masterfile: Afghanistan
# we created dataset from the masterfile: Albania
# we created dataset from the masterfile: Algeria
# we created dataset from the masterfile: American Samoa
# we created dataset from the masterfile: Andean Latin America
# we created dataset from the masterfile: Andorra
# we created dataset from the masterfile: Angola
# we created dataset from the masterfile: Antigua and Barbuda
# we created dataset from the masterfile: Argentina
# we created dataset from the masterfile: Armenia

# %% [markdown]
# ## Section II: VISUALISATION
# a. Using the same dataset, run a loop to generate up to 10 infographics using a suitable python library to visualize trends. The infographics need to be of the same format - i.e., you are required to generate them in a loop. Kindly document your steps as you go through the process.
#
# b. Write up an article (~500 words) for any one, or a combination of, these infographics.

# %%
# FInding the correlations between the features!!
corr1= df[['Diabetes (deaths)', 'Respiratory diseases (deaths)', 'Cardiovascular diseases (deaths)', 'Kidney disease (deaths)', 'Liver diseases (deaths)', 'Parkinson disease (deaths)', 'Meningitis (deaths)']].corr()
corr1
# Out:
#                                   Diabetes (deaths)  \
# Diabetes (deaths)                             1.000
# Respiratory diseases (deaths)                 1.000
# Cardiovascular diseases (deaths)              1.000
# Kidney disease (deaths)                       1.000
# Liver diseases (deaths)                       1.000
# Parkinson disease (deaths)                    1.000
# Meningitis (deaths)                           0.999
#
#                                   Respiratory diseases (deaths)  \
# Diabetes (deaths)                                         1.000
# Respiratory diseases (deaths)                             1.000
# Cardiovascular diseases (deaths)                          1.000
# Kidney disease (deaths)                                   1.000
# Liver diseases (deaths)                                   1.000
# Parkinson disease (deaths)                                1.000
# Meningitis (deaths)                                       0.999
#
#                                   Cardiovascular diseases (deaths)  \
# Diabetes (deaths)                                            1.000
# Respiratory diseases (deaths)                                1.000
# Cardiovascular diseases (deaths)                             1.000
# Kidney disease (deaths)                                      1.000
# Liver diseases (deaths)                                      1.000
# Parkinson disease (deaths)                                   1.000
# Meningitis (deaths)                                          0.999
#
#                                   Kidney disease (deaths)  \
# Diabetes (deaths)                                   1.000
# Respiratory diseases (deaths)                       1.000
# Cardiovascular diseases (deaths)                    1.000
# Kidney disease (deaths)                             1.000
# Liver diseases (deaths)                             1.000
# Parkinson disease (deaths)                          1.000
# Meningitis (deaths)                                 0.999
#
#                                   Liver diseases (deaths)  \
# Diabetes (deaths)                                   1.000
# Respiratory diseases (deaths)                       1.000
# Cardiovascular diseases (deaths)                    1.000
# Kidney disease (deaths)                             1.000
# Liver diseases (deaths)                             1.000
# Parkinson disease (deaths)                          1.000
# Meningitis (deaths)                                 1.000
#
#                                   Parkinson disease (deaths)  \
# Diabetes (deaths)                                      1.000
# Respiratory diseases (deaths)                          1.000
# Cardiovascular diseases (deaths)                       1.000
# Kidney disease (deaths)                                1.000
# Liver diseases (deaths)                                1.000
# Parkinson disease (deaths)                             1.000
# Meningitis (deaths)                                    0.999
#
#                                   Meningitis (deaths)
# Diabetes (deaths)                               0.999
# Respiratory diseases (deaths)                   0.999
# Cardiovascular diseases (deaths)                0.999
# Kidney disease (deaths)                         0.999
# Liver diseases (deaths)                         1.000
# Parkinson disease (deaths)                      0.999
# Meningitis (deaths)                             1.000

# %% [markdown]
# We can say that from our correlation factor value that it is high chance patient who dies from Diabetes have some Liver disease aswell ~98.1%

# %%
## creating a loop to plot different coutries graphs based on Year and Suicide deaths
# for i in country_lst:
#     grp = df.groupby(df.Entity) ## grouping the columns
#     temp = grp.get_group(i)
#     print(f'we created graphs from the masterfile based on suicide deaths and year: { i}')
#     plt.plot(temp['Year'], temp['Suicide (deaths)'])
#     plt.title(i)
#     plt.xlabel('Years')
#     plt.ylabel('Deaths')
#     plt.show()

# %%
## creating a loop to plot 10 different coutries graphs based on Year and Suicide deaths
for i in country_lst[:10]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on suicide deaths and year: { i}')
    plt.plot(temp['Year'], temp['Suicide (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on suicide deaths and year: Afghanistan
# we created graphs from the masterfile based on suicide deaths and year: Albania
# we created graphs from the masterfile based on suicide deaths and year: Algeria
# we created graphs from the masterfile based on suicide deaths and year: American Samoa
# we created graphs from the masterfile based on suicide deaths and year: Andean Latin America
# we created graphs from the masterfile based on suicide deaths and year: Andorra
# we created graphs from the masterfile based on suicide deaths and year: Angola
# we created graphs from the masterfile based on suicide deaths and year: Antigua and Barbuda
# we created graphs from the masterfile based on suicide deaths and year: Argentina
# we created graphs from the masterfile based on suicide deaths and year: Armenia

# %%
from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('multipage.pdf')
plt.savefig(pp, format='pdf')

# %%
## creating a loop to plot 10 different coutries scatter graphs based on Year and Suicide deaths
for i in country_lst[:10]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on suicide deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Suicide (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on suicide deaths and year: Afghanistan
# we created graphs from the masterfile based on suicide deaths and year: Albania
# we created graphs from the masterfile based on suicide deaths and year: Algeria
# we created graphs from the masterfile based on suicide deaths and year: American Samoa
# we created graphs from the masterfile based on suicide deaths and year: Andean Latin America
# we created graphs from the masterfile based on suicide deaths and year: Andorra
# we created graphs from the masterfile based on suicide deaths and year: Angola
# we created graphs from the masterfile based on suicide deaths and year: Antigua and Barbuda
# we created graphs from the masterfile based on suicide deaths and year: Argentina
# we created graphs from the masterfile based on suicide deaths and year: Armenia

# %% [markdown]
# From the above graph we come into a conclusion that Argentina have thee maximums deaths due to Suicide around ~5500 from year 2013- 2017

# %%
for i in country_lst[::10]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on Terrorism deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Terrorism (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
    plt.savefig('plot.pdf')
    plt.savefig(pp, format='pdf')
# Out:
# we created graphs from the masterfile based on Terrorism deaths and year: Afghanistan
# we created graphs from the masterfile based on Terrorism deaths and year: Australasia
# we created graphs from the masterfile based on Terrorism deaths and year: Belgium
# we created graphs from the masterfile based on Terrorism deaths and year: Brunei
# we created graphs from the masterfile based on Terrorism deaths and year: Central America & Caribbean
# we created graphs from the masterfile based on Terrorism deaths and year: Comoros
# we created graphs from the masterfile based on Terrorism deaths and year: Denmark
# we created graphs from the masterfile based on Terrorism deaths and year: Egypt
# we created graphs from the masterfile based on Terrorism deaths and year: French Guiana
# we created graphs from the masterfile based on Terrorism deaths and year: Guadeloupe
# we created graphs from the masterfile based on Terrorism deaths and year: High-middle SDI
# we created graphs from the masterfile based on Terrorism deaths and year: Ireland
# we created graphs from the masterfile based on Terrorism deaths and year: Kuwait
# we created graphs from the masterfile based on Terrorism deaths and year: Low SDI
# we created graphs from the masterfile based on Terrorism deaths and year: Malta
# we created graphs from the masterfile based on Terrorism deaths and year: Mongolia
# we created graphs from the masterfile based on Terrorism deaths and year: Nicaragua
# we created graphs from the masterfile based on Terrorism deaths and year: Oman
# we created graphs from the masterfile based on Terrorism deaths and year: Puerto Rico
# we created graphs from the masterfile based on Terrorism deaths and year: Saudi Arabia
# we created graphs from the masterfile based on Terrorism deaths and year: Solomon Islands
# we created graphs from the masterfile based on Terrorism deaths and year: Southern Sub-Saharan Africa
# we created graphs from the masterfile based on Terrorism deaths and year: Taiwan
# we created graphs from the masterfile based on Terrorism deaths and year: Turkey
# we created graphs from the masterfile based on Terrorism deaths and year: Uzbekistan
# we created graphs from the masterfile based on Terrorism deaths and year: World

# %% [markdown]
# I plotted different scatter plots to get insights that which country have the highest deaths due to terrorism!!
# we get out answer from the plots that contry Afghanistan had most deaths from Terrrorism of around 6000 people deaths in year 2015-2017
#
# And the country which have least deaths from terrorism is Comoros which is almost 0 since 1994- 2000 and 1 case was happened in year 1992 only!

# %%
df.head()
# Out:
#         Entity Code     Year Execution  Meningitis (deaths)  \
# 0  Afghanistan  AFG 2007.000        15             9121.086
# 1  Afghanistan  AFG 2008.000        17             8387.057
# 2  Afghanistan  AFG 2009.000         0             7318.273
# 3  Afghanistan  AFG 2010.000       NaN             7154.319
# 4  Afghanistan  AFG 2011.000         2             6919.758
#
#    Lower respiratory infections (deaths)  \
# 0                              29066.442
# 1                              26623.481
# 2                              24792.336
# 3                              23950.017
# 4                              23115.145
#
#    Intestinal infectious diseases (deaths)  \
# 0                                  461.195
# 1                                  437.719
# 2                                  415.777
# 3                                  332.254
# 4                                  299.758
#
#    Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# 0                              1846.997            1199.000
# 1                              1681.270            1092.000
# 2                              1568.095            1065.000
# 3                              1541.841            1157.000
# 4                              1468.204            1525.000
#
#    Cardiovascular diseases (deaths)  Dementia (deaths)  \
# 0                         53532.680           2458.120
# 1                         53402.322           2496.968
# 2                         53024.451           2537.091
# 3                         52712.688           2575.132
# 4                         52815.737           2615.884
#
#    Kidney disease (deaths)  Respiratory diseases (deaths)  \
# 0                 3715.278                       6896.159
# 1                 3685.770                       6855.287
# 2                 3661.267                       6778.041
# 3                 3682.829                       6734.346
# 4                 3691.336                       6708.237
#
#    Liver diseases (deaths)  Digestive diseases (deaths)  Hepatitis (deaths)  \
# 0                 1930.047                     4922.241            1050.289
# 1                 1933.357                     4876.682            1013.520
# 2                 1931.724                     4825.603             979.689
# 3                 1962.716                     4839.885             969.141
# 4                 1988.639                     4850.470             953.248
#
#    Cancers (deaths)  Parkinson disease (deaths)  Fire (deaths)  \
# 0         14253.281                     400.811        498.392
# 1         14385.275                     404.781        476.395
# 2         14458.354                     408.437        455.526
# 3         14645.749                     411.765        459.466
# 4         14868.810                     416.461        457.994
#
#    Malaria (deaths)  Drowning (deaths)  Homicide (deaths)  HIV/AIDS (deaths)  \
# 0          1118.397           2494.128           3029.128            144.504
# 1          1121.698           2281.337           3074.296            153.260
# 2          1099.001           2085.922           3073.230            158.886
# 3          1081.649           2080.645           3242.287            169.382
# 4          1043.741           2025.107           3230.754            176.560
#
#    Drug use disorders (deaths)  Tuberculosis (deaths)  Road injuries (deaths)  \
# 0                      209.683               4859.484                8099.405
# 1                      220.170               4589.263                8038.390
# 2                      229.249               4326.663                7879.711
# 3                      240.723               4154.390                7970.424
# 4                      253.542               4009.264                8051.536
#
#    Maternal disorders (deaths)  Neonatal disorders (deaths)  \
# 0                     4810.834                    28477.081
# 1                     4873.807                    28234.016
# 2                     4819.714                    27897.481
# 3                     4716.802                    27018.707
# 4                     4626.999                    27198.629
#
#    Alcohol use disorders (deaths)  Natural disasters (deaths)  \
# 0                          96.028                     296.000
# 1                          98.308                       0.000
# 2                         100.089                     101.000
# 3                         102.648                     350.000
# 4                         105.565                      62.000
#
#    Diarrheal diseases (deaths)  Heat (hot and cold exposure) (deaths)  \
# 0                    10366.124                                160.930
# 1                     8994.816                                156.861
# 2                     7996.530                                152.144
# 3                     7530.047                                151.683
# 4                     7053.113                                150.312
#
#    Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 0                           1941.282          1378.572           8216.001
# 1                           1765.981          1411.783           6749.000
# 2                           1647.863          1428.808           7562.996
# 3                           1619.355          1457.158           8117.001
# 4                           1543.183          1496.192           9061.000
#
#    Diabetes (deaths)  Poisonings (deaths)  Total_Deaths
# 0           4691.007              305.207    212045.815
# 1           4750.241              300.246    204565.358
# 2           4784.225              295.414    199858.591
# 3           4825.934              304.809    198262.790
# 4           4954.294              311.998    198048.470

# %%
## created dfx dataframe to add a row column for total sum of the each diseases!
m= df
m.loc['Diseases deaths']=df.iloc[:, 4:-1].sum(axis= 0)
dfx= pd.DataFrame(m)
dfx

df_neural_diseases= dfx[['Meningitis (deaths)', 'Dementia (deaths)', 'Parkinson disease (deaths)']]
df_neural_diseases
# Out:
#                  Meningitis (deaths)  Dementia (deaths)  \
# 0                           9121.086           2458.120
# 1                           8387.057           2496.968
# 2                           7318.273           2537.091
# 3                           7154.319           2575.132
# 4                           6919.758           2615.884
# ...                              ...                ...
# 6682                        1897.210           1410.146
# 6683                        1972.102           1385.625
# 6684                        2021.646           1363.448
# 6685                        1677.007           1246.101
# Diseases deaths        100652027.180      447626326.261
#
#                  Parkinson disease (deaths)
# 0                                   400.811
# 1                                   404.781
# 2                                   408.437
# 3                                   411.765
# 4                                   416.461
# ...                                     ...
# 6682                                207.181
# 6683                                203.544
# 6684                                199.712
# 6685                                182.254
# Diseases deaths                62618198.233
#
# [6687 rows x 3 columns]

# %%
df[['Meningitis (deaths)', 'Dementia (deaths)', 'Parkinson disease (deaths)']].sum(axis = 0, skipna = True)
# Out:
# Meningitis (deaths)          150978040.770
# Dementia (deaths)            671439489.392
# 4504               24257.628                    21646.259
# 4514               38123.762                    23841.371
#
#       Neonatal disorders (deaths)  Alcohol use disorders (deaths)  \
# 2758                   611935.770                       19839.972
# 2768                   848729.497                       12078.115
# 2778                   743305.419                       15953.355
# 4494                   224945.859                        1131.411
# 4504                   211576.654                         611.017
# 4514                   228611.627                         873.257
#
#       Natural disasters (deaths)  Diarrheal diseases (deaths)  \
# 2758                    2051.000                   812465.737
# 2768                    2070.821                   977087.282
# 2778                    2242.438                   905534.476
# 4494                     102.000                    84334.405
# 4504                    1486.000                   135911.792
# 4514                      76.000                    86637.506
#
#       Heat (hot and cold exposure) (deaths)  \
# 2758                              13335.699
# 2768                              11597.440
# 2778                              13306.886
# 4494                                605.517
# 4504                                534.464
# 4514                                689.099
#
#       Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 2758                          70405.759        190578.992           3031.283
# 2768                         121873.668        160025.452           3805.095
# 2778                          96968.773        192670.865           5458.141
# 4494                           6381.116          7948.423           8400.000
# 4504                           8715.613          4566.631            149.000
# 4514                           6878.741          7307.860            149.000
#
#       Diabetes (deaths)  Poisonings (deaths)  Total_Deaths
# 2758         165465.456             6227.704   8123521.720
# 2768          75208.313             7000.591   7513589.069
# 2778         123279.118             6820.135   8071990.221
# 4494          28321.430             1436.059   1297208.999
# 4504          11002.017             1222.561   1091661.869
# 4514          19266.908             1404.327   1205592.270

# %%
date= ind_pak['Year']

# %%
date_time=pd.to_datetime(date, format='%Y')
date1=date_time[:28]

# %%
ind_pak_terror= ind_pak[['Entity', 'Terrorism (deaths)']]
ind_pak_terror[::10]
# Out:
#         Entity  Terrorism (deaths)
# 2758     India             626.000
# 2768     India             907.000
# 2778     India             671.000
# 4494  Pakistan            1487.000
# 4504  Pakistan             152.000
# 4514  Pakistan             105.000

# %%
x= ind_pak_terror.loc[df['Entity']== 'Pakistan']
y= ind_pak_terror.loc[df['Entity']== 'India']

# %%
x.reset_index(drop = True).filter('Terrorism (deaths)')
# plt.scatter(x,y, c='coral')
xx= x['Terrorism (deaths)'].values
xx
# Out:
# array([1406., 1184., 1487., 1699., 1676., 2784., 2875., 2413., 1608.,
#        1113.,  188.,  231.,  152.,   nan,  354.,  712.,  423.,  443.,
#         151.,  127.,  118.,  109.,  105.,  119.,  304.,  152.,  315.,
#        1076.])

# %%
y.reset_index(drop = True).filter('Terrorism (deaths)')
# plt.scatter(x,y, c='coral')
yy= y['Terrorism (deaths)'].values 
yy
# Out:
# array([ 626.,  824.,  774.,  812.,  499.,  264.,  467.,  490.,  387.,
#         467.,  907., 1113., 1152.,   nan,  389.,  361.,  569.,  853.,
#         398.,  469.,  671.,  660.,  599.,  472.,  334.,  466.,  722.,
#         465.])

# %%
plt.scatter(date1, xx)
plt.xlabel('Years')
plt.ylabel('Terrotism Deaths')
plt.title('Pakistan')

plt.plot(date1, xx)
plt.xlabel('Years')
plt.ylabel('Terrotism Deaths')
plt.title('Pakistan')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Pakistan')

# %% [markdown]
# From the above graph we came upto a conclusion that there is a surge in terrorrism attack in Pakistan during 1996- 2003 and during 2010- 2013.
#
# highest death was in year 2013 which was around 3000 deaths

# %%
plt.scatter(date1, yy)
plt.xlabel('Years')
plt.ylabel('Terrotism Deaths')
plt.title('India')

plt.plot(date1, yy)
plt.xlabel('Years')
plt.ylabel('Terrotism Deaths')
plt.title('India')
# Out:
# Text(0.5, 1.0, 'India')

# %% [markdown]
# I created a new data frame for country name India and Pakistan using all death causes colummns. Then comparing the terrorism deaths and Cardiovascular Heart diseases deaths.
#
# From our Terrorism and deaths graph we can say that there was terror attack in Pakistan which killed around 2700 people in Pakistan during year 2010 -2013.
#
# And In India there was a surge in terror attack during year 2004 – 2012 which killed around 700 people deaths per annum.

# %%
alc_neur_prob= df[['Alcohol use disorders (deaths)', 'Drug use disorders (deaths)', 'Parkinson disease (deaths)']]
alc_neur_prob.corr()
# Out:
#                                 Alcohol use disorders (deaths)  \
# Alcohol use disorders (deaths)                           1.000
# Drug use disorders (deaths)                              1.000
# Parkinson disease (deaths)                               1.000
#
#                                 Drug use disorders (deaths)  \
# Alcohol use disorders (deaths)                        1.000
# Drug use disorders (deaths)                           1.000
# Parkinson disease (deaths)                            1.000
#
#                                 Parkinson disease (deaths)
# Alcohol use disorders (deaths)                       1.000
# Drug use disorders (deaths)                          1.000
# Parkinson disease (deaths)                           1.000

# %%
ind_pak_CardioDeaths= ind_pak[['Entity', 'Cardiovascular diseases (deaths)']]
ind_pak_CardioDeaths[::10]
# Out:
#         Entity  Cardiovascular diseases (deaths)
# 2758     India                       1818917.124
# 2768     India                       1271309.695
# 2778     India                       1554528.791
# 4494  Pakistan                        313037.385
# 4504  Pakistan                        215315.724
# 4514  Pakistan                        278572.693

# %%
x= ind_pak_CardioDeaths.loc[df['Entity']== 'Pakistan']
y= ind_pak_CardioDeaths.loc[df['Entity']== 'India']

# %% [markdown]
# We can see that there is a high correlation between those use drugs are addicted by alcohals and also have a high chance of Parkinson death in future!!

# %%
y.reset_index(drop = True).filter('Cardiovascular diseases (deaths)')
# plt.scatter(x,y, c='coral')
yy= y['Cardiovascular diseases (deaths)'].values 
yy
# Out:
# array([1818917.12360826, 1909307.0484475 , 1996193.94629486,
#        2095861.75395036, 2197148.82843644, 2285130.73951377,
#        2351070.08543449, 2418358.18789851, 2490513.24804719,
#        2583708.75268352, 1271309.69464708, 1305340.72931709,
#        1344348.57290916, 1348539.59649654, 1362480.34674732,
#        1371685.90963897, 1408164.75447808, 1504952.39493972,
#        1536981.79642767, 1525906.17612525, 1554528.79108923,
#        1592379.96467502, 1615888.6412779 , 1625441.56090489,
#        1595409.23532373, 1653598.71055202, 1734072.27169274,
#        2632779.77588439])

# %%
plt.scatter(date1, yy)
plt.xlabel('Years')
plt.ylabel('Cardiovascular diseases (deaths)')
plt.title('India')


plt.xlabel('Years')
plt.ylabel('Cardiovascular diseases (deaths)')
# Out:
# Text(0, 0.5, 'Cardiovascular diseases (deaths)')

# %% [markdown]
# In india Cardiovascular heart problems are increases significantly from year 2010- 2017 which cause deaths of around 2700000 people

# %%
x.reset_index(drop = True).filter('Cardiovascular diseases (deaths)')
# plt.scatter(x,y, c='coral')
xx= x['Cardiovascular diseases (deaths)'].values 
xx
# Out:
# array([302305.54363464, 307782.82266513, 313037.3854698 , 319323.92130539,
#        326241.90457586, 334172.99771951, 342768.91922427, 352846.14790008,
#        362180.27759866, 372093.20214149, 197458.87723393, 208558.15778145,
#        215315.72404196, 222888.96359863, 231700.35141231, 244283.00812745,
#        250654.60101508, 259233.24491889, 262637.03710032, 265822.66313473,
#        269547.5265788 , 273972.81555537, 278572.69343782, 284160.24510209,
#        289510.52780992, 295320.8978163 , 298835.17581665, 381421.31113745])

# %%
plt.scatter(date1, xx)
plt.xlabel('Years')
plt.ylabel('Cardiovascular diseases (deaths)')
plt.title('Pakistan')

plt.xlabel('Years')
plt.ylabel('Cardiovascular diseases (deaths)')
# Out:
# Text(0, 0.5, 'Cardiovascular diseases (deaths)')

# %% [markdown]
# In Pakistan Cardiovascular heart problems are increases significantly from year 2012- 2017 which cause deaths of around 400000 people

# %% [markdown]
# So here we can conclude that people who died due to cardiovascular disesases are higher in Inida as compare to Pakistan by around 2300000 people

# %%
## convert the jupyter notebook into Pdf format

# %%
# pip install -U notebook-as-pdf

# %%
df
# Out:
#                       Entity Code     Year Execution  Meningitis (deaths)  \
# 0                Afghanistan  AFG 2007.000        15             9121.086
# 1                Afghanistan  AFG 2008.000        17             8387.057
# 2                Afghanistan  AFG 2009.000         0             7318.273
# 3                Afghanistan  AFG 2010.000       NaN             7154.319
# 4                Afghanistan  AFG 2011.000         2             6919.758
# ...                      ...  ...      ...       ...                  ...
# 6682                Zimbabwe  ZWE 2004.000       NaN             1897.210
# 6683                Zimbabwe  ZWE 2005.000       NaN             1972.102
# 6684                Zimbabwe  ZWE 2006.000       NaN             2021.646
# 6685                Zimbabwe  ZWE 2017.000       NaN             1677.007
# Diseases deaths          NaN  NaN      nan       NaN        100652027.180
#
#                  Lower respiratory infections (deaths)  \
# 0                                            29066.442
# 1                                            26623.481
# 2                                            24792.336
# 3                                            23950.017
# 4                                            23115.145
# ...                                                ...
# 6682                                         11912.788
# 6683                                         12332.751
# 6684                                         12679.065
# 6685                                         12369.655
# Diseases deaths                          757113963.207
#
#                  Intestinal infectious diseases (deaths)  \
# 0                                                461.195
# 1                                                437.719
# 2                                                415.777
# 3                                                332.254
# 4                                                299.758
# ...                                                  ...
# 6682                                              15.859
# 6683                                              17.191
# 6684                                              18.192
# 6685                                                 nan
# Diseases deaths                             42233060.771
#
#                  Protein-energy malnutrition (deaths)  Terrorism (deaths)  \
# 0                                            1846.997            1199.000
# 1                                            1681.270            1092.000
# 2                                            1568.095            1065.000
# 3                                            1541.841            1157.000
# 4                                            1468.204            1525.000
# ...                                               ...                 ...
# 6682                                         2987.046                 nan
# 6683                                         3154.258                 nan
# 6684                                         3252.216               0.000
# 6685                                         3111.874               0.000
# Diseases deaths                         103076267.234         2019282.000
#
#                  Cardiovascular diseases (deaths)  Dementia (deaths)  \
# 0                                       53532.680           2458.120
# 1                                       53402.322           2496.968
# 2                                       53024.451           2537.091
# 3                                       52712.688           2575.132
# 4                                       52815.737           2615.884
# ...                                           ...                ...
# 6682                                    18424.762           1410.146
# 6683                                    18523.611           1385.625
# 6684                                    18478.630           1363.448
# 6685                                    16976.902           1246.101
# Diseases deaths                    3884105357.301      447626326.261
#
#                  Kidney disease (deaths)  Respiratory diseases (deaths)  \
# 0                               3715.278                       6896.159
# 1                               3685.770                       6855.287
# 2                               3661.267                       6778.041
# 3                               3682.829                       6734.346
# 4                               3691.336                       6708.237
# ...                                  ...                            ...
# 6682                            1728.791                       3761.851
# 6683                            1743.115                       3814.769
# 6684                            1756.603                       3814.640
# 6685                            1739.892                       3411.961
# Diseases deaths            231419904.222                  922270411.156
#
#                  Liver diseases (deaths)  Digestive diseases (deaths)  \
# 0                               1930.047                     4922.241
# 1                               1933.357                     4876.682
# 2                               1931.724                     4825.603
# 3                               1962.716                     4839.885
# 4                               1988.639                     4850.470
# ...                                  ...                          ...
# 6682                            1765.617                     3415.759
# 6683                            1766.218                     3428.316
# 6684                            1755.853                     3425.895
# 6685                            1439.682                     3387.438
# Diseases deaths            293702821.280                534132858.500
#
#                  Hepatitis (deaths)  Cancers (deaths)  \
# 0                          1050.289         14253.281
# 1                          1013.520         14385.275
# 2                           979.689         14458.354
# 3                           969.141         14645.749
# 4                           953.248         14868.810
# ...                             ...               ...
# 6682                        142.474         11686.587
# 6683                        146.372         11483.874
# 6684                        152.360         11372.576
# 6685                        134.990         11439.823
# Diseases deaths        34868111.333    2020720877.551
#
#                  Parkinson disease (deaths)  Fire (deaths)  Malaria (deaths)  \
# 0                                   400.811        498.392          1118.397
# 1                                   404.781        476.395          1121.698
# 2                                   408.437        455.526          1099.001
# 3                                   411.765        459.466          1081.649
# 4                                   416.461        457.994          1043.741
# ...                                     ...            ...               ...
# 6682                                207.181        642.378          1014.828
# 6683                                203.544        651.600           991.226
# 6684                                199.712        652.754          1061.742
# 6685                                182.254        592.246           685.682
# Diseases deaths                62618198.233   35554565.384     215926049.750
#
#                  Drowning (deaths)  Homicide (deaths)  HIV/AIDS (deaths)  \
# 0                         2494.128           3029.128            144.504
# 1                         2281.337           3074.296            153.260
# 2                         2085.922           3073.230            158.886
# 3                         2080.645           3242.287            169.382
# 4                         2025.107           3230.754            176.560
# ...                            ...                ...                ...
# 6682                       794.076           1427.882         103755.409
# 6683                       806.129           1415.611         102976.340
# 6684                       808.293           1369.332         100640.234
# 6685                       730.094           1179.900          16065.330
# Diseases deaths      107736119.862      111436554.640      363272534.756
#
#                  Drug use disorders (deaths)  Tuberculosis (deaths)  \
# 0                                    209.683               4859.484
# 1                                    220.170               4589.263
# 2                                    229.249               4326.663
# 3                                    240.723               4154.390
# 4                                    253.542               4009.264
# ...                                      ...                    ...
# 6682                                 235.815              13503.031
# 6683                                 242.040              14396.577
# 6684                                 244.470              14856.126
# 6685                                 255.802              11958.067
# Diseases deaths                 29448866.334          372441214.745
#
#                  Road injuries (deaths)  Maternal disorders (deaths)  \
# 0                              8099.405                     4810.834
# 1                              8038.390                     4873.807
# 2                              7879.711                     4819.714
# 3                              7970.424                     4716.802
# 4                              8051.536                     4626.999
# ...                                 ...                          ...
# 6682                           3030.415                     1728.325
# 6683                           3048.520                     1775.762
# 6684                           3020.736                     1815.725
# 6685                           2729.900                     1180.699
# Diseases deaths           330640593.212                 68589022.944
#
#                  Neonatal disorders (deaths)  Alcohol use disorders (deaths)  \
# 0                                  28477.081                          96.028
# 1                                  28234.016                          98.308
# 2                                  27897.481                         100.089
# 3                                  27018.707                         102.648
# 4                                  27198.629                         105.565
# ...                                      ...                             ...
# 6682                                8244.393                          81.526
# 6683                                8613.068                          81.773
# 6684                                9022.460                          81.993
# 6685                                8411.916                          77.192
# Diseases deaths                622698852.780                    45610732.879
#
#                  Natural disasters (deaths)  Diarrheal diseases (deaths)  \
# 0                                   296.000                    10366.124
# 1                                     0.000                     8994.816
# 2                                   101.000                     7996.530
# 3                                   350.000                     7530.047
# 4                                    62.000                     7053.113
# ...                                     ...                          ...
# 6682                                  0.000                     3975.117
# 6683                                  0.000                     4138.830
# 6684                                  0.000                     4337.462
# 6685                                  0.000                     4602.594
# Diseases deaths                13360385.088                506867735.257
#
#                  Heat (hot and cold exposure) (deaths)  \
# 0                                              160.930
# 1                                              156.861
# 2                                              152.144
# 3                                              151.683
# 4                                              150.312
# ...                                                ...
# 6682                                            45.307
# 6683                                            46.064
# 6684                                            46.824
# 6685                                            41.434
# Diseases deaths                           17537467.435
#
#                  Nutritional deficiencies (deaths)  Suicide (deaths)  \
# 0                                         1941.282          1378.572
# 1                                         1765.981          1411.783
# 2                                         1647.863          1428.808
# 3                                         1619.355          1457.158
# 4                                         1543.183          1496.192
# ...                                            ...               ...
# 6682                                      3048.142          2868.490
# 6683                                      3215.817          2897.899
# 6684                                      3313.276          2894.016
# 6685                                      3157.592          2647.469
# Diseases deaths                      114344507.437     212523775.358
#
#                  Conflict (deaths)  Diabetes (deaths)  Poisonings (deaths)  \
# 0                         8216.001           4691.007              305.207
# 1                         6749.000           4750.241              300.246
# 2                         7562.996           4784.225              295.414
# 3                         8117.001           4825.934              304.809
# 4                         9061.000           4954.294              311.998
# ...                            ...                ...                  ...
# 6682                         1.000           2544.639              388.288
# 6683                         3.000           2581.364              396.434
# 6684                         0.000           2609.324              401.036
# 6685                         5.000           2746.740              405.377
# Diseases deaths       28100583.247      252030769.029         21173004.961
#
#                  Total_Deaths
# 0                  212045.815
# 1                  204565.358
# 2                  199858.591
# 3                  198262.790
# 4                  198048.470
# ...                       ...
# 6682               206685.131
# 6683               208249.797
# 6684               207466.640
# 6685               114590.611
# Diseases deaths           nan
#
# [6687 rows x 38 columns]

# %%
for i in country_lst[:15]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on Liver diseases deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Liver diseases (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on Liver diseases deaths and year: Afghanistan
# we created graphs from the masterfile based on Liver diseases deaths and year: Albania
# we created graphs from the masterfile based on Liver diseases deaths and year: Algeria
# we created graphs from the masterfile based on Liver diseases deaths and year: American Samoa
# we created graphs from the masterfile based on Liver diseases deaths and year: Andean Latin America
# we created graphs from the masterfile based on Liver diseases deaths and year: Andorra
# we created graphs from the masterfile based on Liver diseases deaths and year: Angola
# we created graphs from the masterfile based on Liver diseases deaths and year: Antigua and Barbuda
# we created graphs from the masterfile based on Liver diseases deaths and year: Argentina
# we created graphs from the masterfile based on Liver diseases deaths and year: Armenia
# we created graphs from the masterfile based on Liver diseases deaths and year: Australasia
# we created graphs from the masterfile based on Liver diseases deaths and year: Australasia & Oceania
# we created graphs from the masterfile based on Liver diseases deaths and year: Australia
# we created graphs from the masterfile based on Liver diseases deaths and year: Austria
# we created graphs from the masterfile based on Liver diseases deaths and year: Azerbaijan

# %% [markdown]
# Created graphs for liver disease death an dyear of first 10 countries.
# We can conclude from the graphs that coountries name Argentina and Andean Latin America have the most deaths due to Liver diseas of aroound ~10000 and ~13000 in year 2017
#
# And we can also conclude that from the year 2000 there is a significant increase in liver diseases in all of the countries!

# %%
for i in country_lst[::15]:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on Cancer diseases deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Cancers (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on Cancer diseases deaths and year: Afghanistan
# we created graphs from the masterfile based on Cancer diseases deaths and year: Bahamas
# we created graphs from the masterfile based on Cancer diseases deaths and year: Brunei
# we created graphs from the masterfile based on Cancer diseases deaths and year: Central Sub-Saharan Africa
# we created graphs from the masterfile based on Cancer diseases deaths and year: Denmark
# we created graphs from the masterfile based on Cancer diseases deaths and year: Estonia
# we created graphs from the masterfile based on Cancer diseases deaths and year: Guadeloupe
# we created graphs from the masterfile based on Cancer diseases deaths and year: India
# we created graphs from the masterfile based on Cancer diseases deaths and year: Kuwait
# we created graphs from the masterfile based on Cancer diseases deaths and year: Madagascar
# we created graphs from the masterfile based on Cancer diseases deaths and year: Mongolia
# we created graphs from the masterfile based on Cancer diseases deaths and year: North Korea
# we created graphs from the masterfile based on Cancer diseases deaths and year: Puerto Rico
# we created graphs from the masterfile based on Cancer diseases deaths and year: Seychelles
# we created graphs from the masterfile based on Cancer diseases deaths and year: Southern Sub-Saharan Africa
# we created graphs from the masterfile based on Cancer diseases deaths and year: Togo
# we created graphs from the masterfile based on Cancer diseases deaths and year: Uzbekistan
# we created graphs from the masterfile based on Cancer diseases deaths and year: Zambia

# %% [markdown]
# from our graphs we can conclude that among the list of our coutries graphs above country name India and Africa have the maximum cancer deaths which around 900000 and 600000.
#
# Cancer deaths also increases from the year 2007 to 2017 very surgely!

# %%
# created a favourite list of countries!!
fav_conty= df.loc[(df['Entity']== 'India') | (df['Entity']== 'Pakistan') | (df['Entity']== 'Canada') | (df['Entity']== 'United States') | (df['Entity']== 'United Kingdom')]
fav_conty
# Out:
#              Entity Code     Year Execution  Meningitis (deaths)  \
# 1000         Canada  CAN 2007.000       NaN              110.344
# 1001         Canada  CAN 2008.000       NaN              110.195
# 1002         Canada  CAN 2009.000       NaN              109.883
# 1003         Canada  CAN 2010.000       NaN              109.074
# 1004         Canada  CAN 2011.000       NaN              102.772
#       Fire (deaths)  Malaria (deaths)  Drowning (deaths)  Homicide (deaths)  \
# 1000        498.152             0.000            315.275            543.892
# 1001        497.443             0.000            316.245            564.083
# 1002        478.574             0.000            308.331            565.717
# 1003        463.428             0.000            306.261            566.785
# 1004        449.601             0.000            299.905            557.347
# ...             ...               ...                ...                ...
# 6285       5898.347             0.000           4089.540          19843.448
# 6286       5488.012             0.000           4054.919          19552.716
# 6287       5526.623             0.000           4183.935          20070.115
# 6288       5511.816             0.000           4214.771          20665.836
# 6289       5505.231             0.000           4218.396          19880.004
#
#       HIV/AIDS (deaths)  Drug use disorders (deaths)  Tuberculosis (deaths)  \
# 1000            449.486                     1300.542                131.033
# 1001            417.717                     1373.002                126.994
# 1002            366.564                     1438.949                118.699
# 1003            335.224                     1487.956                117.171
# 1004            307.721                     1540.497                115.022
# ...                 ...                          ...                    ...
# 6285          14891.534                    19322.628               1103.270
# 6286          14201.224                    20521.192               1029.472
# 6287          13628.639                    22577.094               1002.034
# 6288          13063.710                    24320.121                969.238
# 6289           7342.708                    67629.285                939.108
#
#       Road injuries (deaths)  Maternal disorders (deaths)  \
# 1000                3009.497                       32.430
# 1001                2910.475                       38.436
# 1002                2781.951                       36.827
# 1003                2674.464                       32.230
# 1004                2557.655                       28.961
# ...                      ...                          ...
# 6285               50125.387                      900.962
# 6286               49143.423                     1013.987
# 6287               49578.158                     1098.506
# 6288               49018.206                     1126.493
# 6289               44213.785                     1171.320
#
#       Neonatal disorders (deaths)  Alcohol use disorders (deaths)  \
# 1000                     1003.039                        1022.058
# 1001                     1017.123                        1057.924
# 1002                      973.574                        1076.916
# 1003                      957.730                        1093.123
# 1004                      920.194                        1102.718
# ...                           ...                             ...
# 6285                    14598.888                        9721.199
# 6286                    14384.996                        9864.207
# 6287                    14686.733                       10250.237
# 6288                    14744.322                       10444.756
# 6289                    11437.055                       13968.926
#
#       Natural disasters (deaths)  Diarrheal diseases (deaths)  \
# 1000                      18.000                     1273.629
# 1001                      21.000                     1393.553
# 1002                      14.000                     1513.251
# 1003                      11.000                     1602.843
# 1004                      19.000                     1657.347
# ...                          ...                          ...
# 6285                     221.918                     4827.245
# 6286                     204.757                     5731.566
# 6287                    2818.040                     6787.285
# 6288                     188.658                     7690.923
# 6289                     103.000                     9505.705
#
#       Heat (hot and cold exposure) (deaths)  \
# 1000                                126.716
# 1001                                126.436
# 1002                                124.211
# 1003                                125.991
# 1004                                125.253
# ...                                     ...
# 6285                               1246.108
# 6286                               1232.691
# 6287                               1340.793
# 6288                               1484.897
# 6289                               1454.881
#
#       Nutritional deficiencies (deaths)  Suicide (deaths)  Conflict (deaths)  \
# 1000                            294.154          4298.378             30.000
# 1001                            302.511          4353.887             32.000
# 1002                            301.135          4386.971             32.000
# 1003                            299.119          4361.720             16.000
# 1004                            296.911          4301.719              0.000
# ...                                 ...               ...                ...
# 6285                           3477.105         37497.130            534.000
# 6286                           3401.285         37557.836            901.000
# 6287                           3493.763         38876.996            945.000
# 6288                           3513.904         39777.339            922.000
# 6289                           4904.563         48799.646              8.850
#
#       Diabetes (deaths)  Poisonings (deaths)  Total_Deaths
# 1000           7012.384              136.088    225690.740
# 1001           6917.377              137.248    229466.686
# 1002           6634.588              137.453    230051.652
# 1003           6358.605              135.654    230196.056
# 1004           6067.564              132.129    231440.477
# ...                 ...                  ...           ...
# 6285          69493.917             1437.756   2367475.520
# 6286          68317.970             1451.084   2333591.876
# 6287          69159.804             1535.513   2370405.349
# 6288          68152.285             1589.678   2368537.352
# 6289          68558.417             1823.258   2760816.390
#
# [140 rows x 38 columns]

# %%
fav_cont= fav_conty['Entity'].unique()

## we converted array to list for using the list method!!
fav_conty_lst = fav_cont.tolist()

# %%
for i in fav_conty_lst:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on Cancer diseases deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Cancers (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on Cancer diseases deaths and year: Canada
# we created graphs from the masterfile based on Cancer diseases deaths and year: India
# we created graphs from the masterfile based on Cancer diseases deaths and year: Pakistan
# we created graphs from the masterfile based on Cancer diseases deaths and year: United Kingdom
# we created graphs from the masterfile based on Cancer diseases deaths and year: United States

# %% [markdown]
# From the cancer death graph of our favourite country list it is clear that in every coutnries there is aan increase in deaths of people from cancer disease.
#
# India has the max deaths rate of around ~900000 in year 2017, and US comes to 2 with around ~700000 deaths in year 2016.
#
# from Our grapgh of UK country we can say that they had taken some measure to control deaths from Cancer in year between 1997- 2000 but again increase from year 2007.

# %%
for i in fav_conty_lst:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on Malaria diseases deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Malaria (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on Malaria diseases deaths and year: Canada
# we created graphs from the masterfile based on Malaria diseases deaths and year: India
# we created graphs from the masterfile based on Malaria diseases deaths and year: Pakistan
# we created graphs from the masterfile based on Malaria diseases deaths and year: United Kingdom
# we created graphs from the masterfile based on Malaria diseases deaths and year: United States

# %% [markdown]
# From our favourite list of countries we can conclude that there is almost no death because of Malaria in United States, UK  and Canada
#
# But Saddenly Malaria deaths in India and Pakistan are signifcantly high around~ 90000 in year between 1990 to 2000 and around~ 6000 in year 2000- 2005 in Pakistan
#
# Although India is decreases the death rate of malaria from last 20 years, but It needs to be eradicated as US and UK.
# It shows that India and PAkistan is more unhygienic and lives in dirty environment that leads to Malaria mosquitoes

# %%
for i in fav_conty_lst:
    grp = df.groupby(df.Entity) ## grouping the columns
    temp = grp.get_group(i)
    print(f'we created graphs from the masterfile based on TB diseases deaths and year: { i}')
    plt.scatter(temp['Year'], temp['Tuberculosis (deaths)'])
    plt.title(i)
    plt.xlabel('Years')
    plt.ylabel('Deaths')
    plt.show()
# Out:
# we created graphs from the masterfile based on TB diseases deaths and year: Canada
# we created graphs from the masterfile based on TB diseases deaths and year: India
# we created graphs from the masterfile based on TB diseases deaths and year: Pakistan
# we created graphs from the masterfile based on TB diseases deaths and year: United Kingdom
# we created graphs from the masterfile based on TB diseases deaths and year: United States

# %% [markdown]
# In India year between 1990- 2000 there were around 600000 died because of TB which was reduces to 400000 in year 2017. But it should be reduced more and India needs to work on the TB health issues.
#
# While in US, UK and Canada it already reducces to less than 800 people died due to TB from year 2000- 2017
